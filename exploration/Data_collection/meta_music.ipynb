# %%
import pandas as pd
from fuzzywuzzy import fuzz, process

# Load the main CSV file containing song name, artist name, and mood
main_df = pd.read_csv('/Users/zac/Codes/Music_Project/GIT_HUB/Musis_Recommendation_Engine/data/testing/SAMPLE_MOOD.csv')

# Load the metadata CSV files
metadata_df1 = pd.read_csv('/Users/zac/Codes/Music_Project/GIT_HUB/Musis_Recommendation_Engine/data/kaggle_dataset/2000_2019.csv')
metadata_df2 = pd.read_csv('/Users/zac/Codes/Music_Project/GIT_HUB/Musis_Recommendation_Engine/data/kaggle_dataset/2020_2023.csv')
metadata_df3 = pd.read_csv('/Users/zac/Codes/Music_Project/GIT_HUB/Musis_Recommendation_Engine/data/kaggle_dataset/1960_2010.csv')

# %%
metadata_df1
# Out:
#               artist                                    song  duration_ms  \
# 0     Britney Spears                  Oops!...I Did It Again       211160
# 1          blink-182                    All The Small Things       167066
# 2         Faith Hill                                 Breathe       250546
# 3           Bon Jovi                            It's My Life       224493
# 4             *NSYNC                             Bye Bye Bye       200560
# ...              ...                                     ...          ...
# 1995  Jonas Brothers                                  Sucker       181026
# 1996    Taylor Swift                            Cruel Summer       178426
# 1997    Blanco Brown                              The Git Up       200593
# 1998       Sam Smith  Dancing With A Stranger (with Normani)       171029
# 1999     Post Malone                                 Circles       215280
#
#       explicit  year  popularity  danceability  energy  key  loudness  mode  \
# ...

# %%
metadata_df2
# Out:
#          Unnamed: 0      artist_name                         track_name  \
# 0                 0       Jason Mraz                    I Won't Give Up
# 1                 1       Jason Mraz                   93 Million Miles
# 2                 2    Joshua Hyslop                   Do Not Let Me Go
# 3                 3     Boyce Avenue                           Fast Car
# 4                 4     Andrew Belle                   Sky's Still Blue
# ...             ...              ...                                ...
# 1159759     1473391     Nicola Conte                      Black Spirits
# 1159760     1473392     Nicola Conte                         Quiet Dawn
# 1159761     1473393       Amon Tobin                  Morning Ms Candis
# 1159762     1473394  Peace Orchestra      Happy Christmas (War Is Over)
# 1159763     1473395     Mo' Horizons  Hit the Road Jack (Pé Na Éstrada)
#
#                        track_id  popularity  year     genre  danceability  \
# ...

# %%
metadata_df1 = metadata_df1.rename(columns={"artist":"artist_name", "song":"track_name"})
metadata_df3 = metadata_df3.rename(columns={"artists":"artist_name", "name":"track_name"})
main_df = main_df.rename(columns={"ARTIST":"artist_name", "NAME":"track_name"})

# %%
# Normalize the artist names in the third metadata file
metadata_df3['artist_name'] = metadata_df3['artist_name'].apply(lambda x: eval(x)[0] if isinstance(x, str) else x)
# Out:
# Traceback (most recent call last):
#
#   File ~/anaconda3/envs/model_music/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3526 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[17], line 2
#     metadata_df3['artist_name'] = metadata_df3['artist_name'].apply(lambda x: eval(x)[0] if isinstance(x, str) else x)
#
#   File ~/anaconda3/envs/model_music/lib/python3.11/site-packages/pandas/core/series.py:4630 in apply
#     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
#   File ~/anaconda3/envs/model_music/lib/python3.11/site-packages/pandas/core/apply.py:1025 in apply
#     return self.apply_standard()
#
#   File ~/anaconda3/envs/model_music/lib/python3.11/site-packages/pandas/core/apply.py:1076 in apply_standard
#     mapped = lib.map_infer(
#
#   File pandas/_libs/lib.pyx:2834 in pandas._libs.lib.map_infer
#
#   Cell In[17], line 2 in <lambda>
# ...

# %%
import ast

metadata_df3['artist_name'] = metadata_df3['artist_name'].apply(lambda x: x.split('[')[1].split(']')[0].strip() if isinstance(x, str) and '[' in x and ']' in x else x)

# %%
metadata_df3
# Out:
#         acousticness          artist_name  danceability  duration_ms  energy  \
# 0             0.9950      Carl Woitschach         0.708       158648  0.1950
# 1             0.9940      Robert Schumann         0.379       282133  0.0135
# 2             0.6040  Seweryn Goszczyński         0.749       104300  0.2200
# 3             0.9950     Francisco Canaro         0.781       180760  0.1300
# 4             0.9900      Frédéric Chopin         0.210       687733  0.2040
# ...              ...                  ...           ...          ...     ...
# 169904        0.1730           DripReport         0.875       163800  0.4430
# 169905        0.0167         Leon Bridges         0.719       167468  0.3850
# 169906        0.5380                 Kygo         0.514       180700  0.5390
# 169907        0.0714            Cash Cash         0.646       167308  0.7610
# 169908        0.1090       Ingrid Andress         0.512       214787  0.4280
#
# ...

# %%
# Function to match songs with fuzzy matching
def get_best_match(row, metadata_df):
    song = row['track_name']
    artist = row['artist_name']
    choices = metadata_df['track_name'].tolist()
    best_match, score = process.extractOne(song, choices, scorer=fuzz.token_sort_ratio)
    if score >= 80:  # Adjust the threshold as needed
        return metadata_df.loc[metadata_df['track_name'] == best_match]
    return pd.DataFrame()

# Initialize an empty DataFrame to store the results
result_df = pd.DataFrame(columns=main_df.columns.tolist() + metadata_df1.columns.tolist()[2:])

# Match and merge data from the first metadata file
for _, row in main_df.iterrows():
    matched_row = get_best_match(row, metadata_df1)
    if not matched_row.empty:
        combined_row = pd.concat([row, matched_row.iloc[0, 2:]], axis=0)
        result_df = result_df.append(combined_row, ignore_index=True)

# Match and merge data from the second metadata file
for _, row in main_df.iterrows():
    matched_row = get_best_match(row, metadata_df2)
    if not matched_row.empty:
        combined_row = pd.concat([row, matched_row.iloc[0, 2:]], axis=0)
        result_df = result_df.append(combined_row, ignore_index=True)

# Match and merge data from the third metadata file
for _, row in main_df.iterrows():
    matched_row = get_best_match(row, metadata_df3)
    if not matched_row.empty:
        combined_row = pd.concat([row, matched_row.iloc[0, 2:]], axis=0)
        result_df = result_df.append(combined_row, ignore_index=True)

# Drop duplicates if any
result_df.drop_duplicates(inplace=True)

# Save the result to a new CSV file
result_df.to_csv('matched_songs_with_metadata.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/xz/_r0ch6ln5pg4h1gmy_hjkcyr0000gn/T/ipykernel_68949/1924887202.py in ?()
#      15 for _, row in main_df.iterrows():
#      16     matched_row = get_best_match(row, metadata_df1)
#      17     if not matched_row.empty:
#      18         combined_row = pd.concat([row, matched_row.iloc[0, 2:]], axis=0)
# ---> 19         result_df = result_df.append(combined_row, ignore_index=True)
#      20
#      21 # Match and merge data from the second metadata file
#      22 for _, row in main_df.iterrows():
#
# ~/anaconda3/envs/model_music/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# ...

# %%
import pandas as pd
from fuzzywuzzy import fuzz, process


# Function to match songs with fuzzy matching
def get_best_match(row, metadata_df):
    song = row['track_name']
    choices = metadata_df['track_name'].tolist()
    best_match, score = process.extractOne(song, choices, scorer=fuzz.token_sort_ratio)
    if score >= 80:  # Adjust the threshold as needed
        return metadata_df.loc[metadata_df['track_name'] == best_match]
    return pd.DataFrame()

# Initialize an empty DataFrame to store the results
result_df = pd.DataFrame()

# Function to combine matched rows and append to result_df
def combine_and_append(row, metadata_df, result_df):
    matched_row = get_best_match(row, metadata_df)
    if not matched_row.empty:
        # Combine the row with matched metadata, ignoring duplicates
        combined_row = pd.concat([row, matched_row.iloc[0].drop(['track_name', 'artist_name'])], axis=0)
        result_df = pd.concat([result_df, pd.DataFrame([combined_row])], ignore_index=True)
    return result_df

# Match and merge data from the first metadata file
for _, row in main_df.iterrows():
    result_df = combine_and_append(row, metadata_df1, result_df)

# Match and merge data from the second metadata file
for _, row in main_df.iterrows():
    result_df = combine_and_append(row, metadata_df2, result_df)

# Match and merge data from the third metadata file
for _, row in main_df.iterrows():
    result_df = combine_and_append(row, metadata_df3, result_df)

# Drop duplicates if any
result_df.drop_duplicates(inplace=True)

# Save the result to a new CSV file
result_df.to_csv('matched_songs_with_metadata.csv', index=False)

# %% [markdown]
# ## Final matching

# %%
# Function to match songs with fuzzy matching considering both track name and artist name
def get_best_match(row, metadata_df):
    song = row['track_name']
    artist = row['artist_name']
    choices = metadata_df.apply(lambda x: f"{x['track_name']} {x['artist_name']}", axis=1).tolist()
    query = f"{song} {artist}"
    best_match, score = process.extractOne(query, choices, scorer=fuzz.token_sort_ratio)
    if score >= 80:  # Adjust the threshold as needed
        matched_row = metadata_df.loc[choices.index(best_match)]
        return matched_row
    return pd.DataFrame()

# Initialize an empty DataFrame to store the results
result_df = pd.DataFrame()

# Function to combine matched rows and append to result_df
def combine_and_append(row, metadata_df, result_df):
    matched_row = get_best_match(row, metadata_df)
    if not matched_row.empty:
        # Combine the row with matched metadata, ignoring duplicates
        combined_row = pd.concat([row, matched_row.drop(['track_name', 'artist_name'])], axis=0)
        result_df = pd.concat([result_df, pd.DataFrame([combined_row])], ignore_index=True)
    return result_df

# Match and merge data from the first metadata file
for _, row in main_df.iterrows():
    result_df = combine_and_append(row, metadata_df1, result_df)

# Match and merge data from the second metadata file
for _, row in main_df.iterrows():
    result_df = combine_and_append(row, metadata_df2, result_df)

# Match and merge data from the third metadata file
for _, row in main_df.iterrows():
    result_df = combine_and_append(row, metadata_df3, result_df)

# Drop duplicates if any
result_df.drop_duplicates(inplace=True)

# Save the result to a new CSV file
result_df.to_csv('matched_songs_with_metadata.csv', index=False)

# %% [markdown]
# ## Final Matching with single CSV

# %%
import pandas as pd
from fuzzywuzzy import fuzz, process

# Load the main CSV file containing song name, artist name, and mood
main_df = pd.read_csv('/Users/zac/Codes/Music_Project/GIT_HUB/Musis_Recommendation_Engine/data/testing/SAMPLE_MOOD.csv')

# Load the metadata CSV files
metadata_df = pd.read_csv('/Users/zac/Codes/Music_Project/GIT_HUB/Musis_Recommendation_Engine/data/kaggle_dataset/combined.csv')

# %%
# Function to match songs with fuzzy matching considering both track name and artist name
def get_best_match(row, metadata_df):
    song = row['track_name']
    artist = row['artist_name']
    choices = metadata_df.apply(lambda x: f"{x['track_name']} {x['artist_name']}", axis=1).tolist()
    query = f"{song} {artist}"
    best_match, score = process.extractOne(query, choices, scorer=fuzz.token_sort_ratio)
    if score >= 80:  # Adjust the threshold as needed
        matched_row = metadata_df.loc[choices.index(best_match)]
        return matched_row
    return pd.DataFrame()

# Initialize an empty DataFrame to store the results
result_df = pd.DataFrame()

# Function to combine matched rows and append to result_df
def combine_and_append(row, metadata_df, result_df):
    matched_row = get_best_match(row, metadata_df)
    if not matched_row.empty:
        # Combine the row with matched metadata, ignoring duplicates
        combined_row = pd.concat([row, matched_row.drop(['track_name', 'artist_name'])], axis=0)
        result_df = pd.concat([result_df, pd.DataFrame([combined_row])], ignore_index=True)
    return result_df

# Match and merge data from the first metadata file
for _, row in main_df.iterrows():
    result_df = combine_and_append(row, metadata_df1, result_df)

# Match and merge data from the second metadata file
for _, row in main_df.iterrows():
    result_df = combine_and_append(row, metadata_df2, result_df)

# Match and merge data from the third metadata file
for _, row in main_df.iterrows():
    result_df = combine_and_append(row, metadata_df3, result_df)

# Drop duplicates if any
result_df.drop_duplicates(inplace=True)

# Save the result to a new CSV file
result_df.to_csv('matched_songs_with_metadata.csv', index=False)
