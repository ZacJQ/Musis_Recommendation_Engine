# %%
import pandas as pd
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report
from joblib import dump, load  # Added import for joblib

base_dir = "/Users/zac/Codes/Music_Project/GIT_HUB/Musis_Recommendation_Engine"
file_path = "data/kaggle_dataset/combined.csv"

dataset = pd.read_csv(os.path.join(base_dir,file_path))

dataset_copy = dataset

# %%
try:
    dataset = dataset.rename(columns={"MOOD":"mood"})
    dataset.drop(columns=["Unnamed: 0"], inplace=True)
except Exception as e:
    print("Already column removed", e)


# Select relevant features
features = ['valence', 'popularity', 'year', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'tempo', 'duration_ms']

# Remove rows with missing values
dataset = dataset.dropna(subset=features)
dataset = dataset.drop(columns=['artist_name','track_name'])

# Select features again after one-hot encoding
features = dataset.columns.tolist()
X = dataset[features]
scaler = StandardScaler()
X_inference = scaler.fit_transform(X)

# %%
print(scaler.mean_ , scaler.scale_)
# Out:
# [ 2.47214034e+05  2.00751986e+03  2.01262480e+01  5.37724253e-01
#   6.20515114e-01  5.27678041e+00 -9.28094887e+00  6.43960642e-01
#   9.29895032e-02  3.43152104e-01  2.40457069e-01  2.20872724e-01
#   4.65472673e-01  1.20810139e+02] [1.46161737e+05 1.60683476e+01 1.73660185e+01 1.83348530e-01
#  2.74658463e-01 3.55033421e+00 5.73399885e+00 4.78827039e-01
#  1.29977995e-01 3.62271377e-01 3.59553798e-01 1.98141563e-01
#  2.68916866e-01 2.99347293e+01]

# %%
loaded_model = load('model_v2.joblib')

# %%
predictions = loaded_model.predict(X_inference)

# %%
type(predictions)
# Out:
# numpy.ndarray

# %%
len(predictions)
# Out:
# 1331673

# %%
dataset_copy['mood'] = predictions

# %%
dataset_copy.drop(columns="Unnamed: 0", axis=0, inplace=True)

# %%
dataset_copy
# Out:
#                           artist_name                      track_name  \
# 0                      Britney Spears          Oops!...I Did It Again
# 1                           blink-182            All The Small Things
# 2                          Faith Hill                         Breathe
# 3                            Bon Jovi                    It's My Life
# 4                              *NSYNC                     Bye Bye Bye
# ...                               ...                             ...
# 1331668              DripReport, Tyga   Skechers (feat. Tyga) - Remix
# 1331669  Leon Bridges, Terrace Martin  Sweeter (feat. Terrace Martin)
# 1331670               Kygo, Oh Wonder                How Would I Know
# 1331671       Cash Cash, Andy Grammer                     I Found You
# 1331672                Ingrid Andress           More Hearts Than Mine
#
#          duration_ms  year  popularity  danceability  energy  key  loudness  \
# 0             211160  2000          77         0.751   0.834    1    -5.444
# 1             167066  1999          79         0.434   0.897    0    -4.918
# 2             250546  1999          66         0.529   0.496    7    -9.007
# 3             224493  2000          78         0.551   0.913    0    -4.063
# 4             200560  2000          65         0.614   0.928    8    -4.806
# ...              ...   ...         ...           ...     ...  ...       ...
# 1331668       163800  2020          75         0.875   0.443    1    -7.461
# 1331669       167468  2020          64         0.719   0.385    8   -10.907
# 1331670       180700  2020          70         0.514   0.539    7    -9.332
# 1331671       167308  2020          70         0.646   0.761    1    -2.557
# 1331672       214787  2020          65         0.512   0.428    0    -7.387
#
#          mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0           0       0.0437        0.3000          0.000018    0.3550    0.894
# 1           1       0.0488        0.0103          0.000000    0.6120    0.684
# 2           1       0.0290        0.1730          0.000000    0.2510    0.278
# 3           0       0.0466        0.0263          0.000013    0.3470    0.544
# 4           0       0.0516        0.0408          0.001040    0.0845    0.879
# ...       ...          ...           ...               ...       ...      ...
# 1331668     1       0.1430        0.1730          0.000032    0.0891    0.306
# 1331669     1       0.0403        0.0167          0.031300    0.1110    0.270
# 1331670     1       0.1050        0.5380          0.002330    0.1080    0.153
# 1331671     1       0.0385        0.0714          0.000000    0.2220    0.472
# 1331672     1       0.0271        0.1090          0.000000    0.1050    0.366
#
#            tempo    mood
# 0         95.053  SCARED
# 1        148.726   HAPPY
# 2        136.859   HAPPY
# 3        119.992  SCARED
# 4        172.656   HAPPY
# ...          ...     ...
# 1331668  100.012   HAPPY
# 1331669  128.000  SCARED
# 1331670  123.700     SAD
# 1331671  129.916   HAPPY
# 1331672   80.588   HAPPY
#
# [1331673 rows x 17 columns]

# %%
dataset_copy.to_csv("Database_with_moods.csv", index=False)
